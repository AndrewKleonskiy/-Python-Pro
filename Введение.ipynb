# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-01-30%20%D0%B2%2018.15.11.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-01-30%20%D0%B2%2018.15.11.png)

# %% [markdown]
# **Листинг 1.1. Получение столиц штатов в алфавитном порядке**

# %%
us_capitals_by_state = {'Alabama':'Montgomery','Alaska':'Juneau'}

# %%
capitals = us_capitals_by_state.values()

# %%
sorted(capitals)
# Out:
# ['Juneau', 'Montgomery']

# %% [markdown]
# **Листинг 1.2. Обертывание логики столицы штата в функцию**

# %%
def get_united_states_capitals():
    us_capitals_by_state = {'Alabama':'Montgomery','Alaska':'Juneau'}
    capitals = us_capitals_by_state.values()
    return sorted(capitals)

# %%
get_united_states_capitals()
# Out:
# ['Juneau', 'Montgomery']

# %% [markdown]
# **Листинг 1.3. Рефакторинг кода проявляет более лаконичное решение**

# %%
US_CAPITALS_BY_STATE = {'Alabama':'Montgomery','Alaska':'Juneau'}
US_CAPITALS = sorted(US_CAPITALS_BY_STATE.values())
